# %% [markdown]
# <a href="https://colab.research.google.com/github/IsuruLakshan170/ComputerVisionTakeHomeAssignment/blob/main/TakeHome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. To reduce the number of intensity levels in an image from 256 to 2, in integer powers of 2. The desired number of intensity levels needs to be a variable input to your program.

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
import cv2
from skimage.color import rgb2gray

image = data.cat()
image=rgb2gray(image)
image =np.rint(image*256).astype(np.uint8)

levels=2
#reducing the number of distinct colors in an image, also known as color quantization
dev =255/(levels-1)
newIm=np.round(image/dev)*dev
fig,arr = plt.subplots(1,2)
arr[0].imshow(image)
arr[0].set_title('Original Image')
arr[1].imshow(newIm)
arr[1].set_title('Converted Image')
# Out:
# Text(0.5, 1.0, 'Converted Image')

# %% [markdown]
# # 2.Load an image and then perform a simple spatial 3x3 average of image pixels. Repeat the process for a 10x10 neighborhood and again for a 20x20 neighborhood.

# %%
kernel2 = np.array([[-1,-1,-1],
                    [-1,8,-1],
                    [-1,-1,-1]])

f,arr = plt.subplots(1,4)
image3K = cv2.blur(image,(3,3))
image10k = cv2.blur(image,(10,10))
image20k = cv2.blur(image,(20,20))

plt.gray()

arr[0].imshow(image)
arr[0].set_title('original')


arr[1].imshow(image3K)
arr[1].set_title('3x3 kernal')

arr[2].imshow(image10k)
arr[2].set_title('10x10 kernal')

arr[3].imshow(image20k)
arr[3].set_title('20x20 kernal')
# Out:
# Text(0.5, 1.0, '20x20 kernal')

# %% [markdown]
# # Rotate an image by 45 and 90 degrees.

# %%
print(f"Image shape : {image.shape}")
print(f"Image datatype : {type(image)}")

plt.gray()
f,arr = plt.subplots(1,3)
arr[0].imshow(image)
arr[0].set_title('Original Image')
# Get the height and width of the image
height, width = image.shape[:2]

# Specify the rotation angle
angle_45 = 45
angle_90 = 90

# Specify the center of the image
center = (width/2, height/2)

# Perform the rotation
rotation_matrix_45 = cv2.getRotationMatrix2D(center, angle_45, 1.0)
rotation_matrix_90 = cv2.getRotationMatrix2D(center, angle_90, 1.0)
rotated_img_45 = cv2.warpAffine(image, rotation_matrix_45, (width, height))
rotated_img_90 = cv2.warpAffine(image, rotation_matrix_90, (width, height))

# Show the rotated image
arr[1].imshow(rotated_img_45)
arr[1].set_title('45 deg rotated ')
arr[2].imshow(rotated_img_90)
arr[2].set_title('90 deg rotated ')
cv2.waitKey(0) # waits for a key event
cv2.destroyAllWindows() # closes all the windows
# Out:
# Image shape : (300, 451)
# Image datatype : <class 'numpy.ndarray'>

# %% [markdown]
# # 4th question

# %%
print(f"Image shape : {image.shape}")
print(f"Image datatype : {type(image)}")

plt.gray()
# 3×3 block
ownsampled_3 = cv2.resize(image, (image.shape[1]//3, image.shape[0]//3), interpolation = cv2.INTER_AREA)
# 5x5 block
ownsampled_5 = cv2.resize(image, (image.shape[1]//5, image.shape[0]//5), interpolation = cv2.INTER_AREA)
# 7x7 block
ownsampled_7 = cv2.resize(image, (image.shape[1]//7, image.shape[0]//7), interpolation = cv2.INTER_AREA)

# display the original and reduced image side by side
fig, arr = plt.subplots(1, 4)

arr[0].imshow(image)
arr[0].set_title('Original Image')
arr[1].imshow(ownsampled_3)
arr[1].set_title('3x3 block')
arr[2].imshow(ownsampled_5)
arr[2].set_title('5x5 block')
arr[3].imshow(ownsampled_7)
arr[3].set_title('7x7 block')
# display the figure
plt.show()
# Out:
# Image shape : (300, 451)
# Image datatype : <class 'numpy.ndarray'>
